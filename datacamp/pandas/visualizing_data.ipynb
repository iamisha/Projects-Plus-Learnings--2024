# %% [markdown]
# **Histograms![histograms.png](data:image/png;base64,...)**
#
# ![bins.png](data:image/png;base64,...)
#
# ![bar_plots.png](data:image/png;base64,...)
#
# ![bar_plots2.png](data:image/png;base64,...)
#
# ![line_plots.png](data:image/png;base64,...)
#
# * Line plots are greate for visualizing changes in numeric variables over time
#
# ![sully_plots.png](data:image/png;base64,...)
#
# ![rotating_axis_levels.png](data:image/png;base64,...)
#
# * We  may want to rotate the x-axis lables to make the text easier to read
#
# * This can be done by passing an angle in degrees with the "rot" argument.
#
# ![scatter_plots.png](data:image/png;base64,...)
#
# * Scatter plots are great for visualizing relationships between two numeric variables.
#
# ![layering_plots.png](data:image/png;base64,...)
#
# ![add_a_legend.png](data:image/png;base64,...)
#
# ![transparency.png](data:image/png;base64,...)
#
#
# **Exercise**
#
# ![avocados.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
avocados = pd.read_csv('avocados.csv')
print(avocados.head())
# Out:
#               Geography Timeframe Current_Year_Week_Ending          Type  \
# 0            Total U.S.    Weekly            1/7/2019 0:00  Conventional
# 1                Albany    Weekly            1/7/2019 0:00  Conventional
# 2               Atlanta    Weekly            1/7/2019 0:00  Conventional
# 3  Baltimore/Washington    Weekly            1/7/2019 0:00  Conventional
# 4                 Boise    Weekly            1/7/2019 0:00  Conventional
#
#    ASP_Current_Year  Total_Bulk_and_Bags_Units   4046_Units   4225_Units  \
# 0              1.02                44749707.48  14377053.08  11890232.90
# 1              1.07                  129222.29      3789.30    112635.18
# 2              0.92                  828971.15    388574.98     38902.85
# 3              1.31                  925391.38    102652.85    530128.43
# 4              1.23                  108261.98     43723.19      7085.86
#
#    4770_Units  TotalBagged_Units  SmlBagged_Units  LrgBagged_Units  \
# ...

# %%
# Look at the first few rows of data
print(avocados.head())

# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby("size")["nb_sold"].sum()

# Create a bar plot of the number of avocados sold by size
avocados["nb_sold"].hist()

# Show the plot
nb_sold_by_size.plot(kind="bar")
plt.show()

# %%
# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")["nb_sold"].sum()

# Create a line plot of the number of avocados sold by date
nb_sold_by_date.plot(kind="line")

# Show the plot
plt.show()

# %%
# Scatter plot of avg_price vs. nb_sold with title
avocados.plot(x="nb_sold", y="avg_price", kind="scatter", title="Number of avocados sold vs. average price")

# Show the plot
plt.show()

# %%
# Histogram of conventional avg_price
avocados[avocados["type"]== "conventional"]["avg_price"] .hist()

# Histogram of organic avg_price
avocados[avocados["type"] == "organic"]["avg_price"].hist()

# Add a legend
plt.legend(["conventional", "organic"])

# Show the plot
plt.show()

# %%
# Modify histogram transparency to 0.5
avocados[avocados["type"] == "conventional"]["avg_price"].hist(alpha=0.5)

# Modify histogram transparency to 0.5
avocados[avocados["type"] == "organic"]["avg_price"].hist(alpha=0.5)

# Add a legend
plt.legend(["conventional", "organic"])

# Show the plot
plt.show()

# %%
# Modify bins to 20
avocados[avocados["type"] == "conventional"]["avg_price"].hist(alpha=0.5, bins=20)

# Modify bins to 20
avocados[avocados["type"] == "organic"]["avg_price"].hist(alpha=0.5, bins=20)

# Add a legend
plt.legend(["conventional", "organic"])

# Show the plot
plt.show()
