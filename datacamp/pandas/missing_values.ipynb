# %% [markdown]
# ![missing_value.png](data:image/png;base64,...)
#
# * In a pandas DataFrame, missing values are indicated with NaN, which stands for "Not a Number"
#
# ![NaN.png](data:image/png;base64,...)
#
# ![depicting_missing_value.png](data:image/png;base64,...)
#
# * here, we see that there's at least one missing value in the weight column, but not in any of others
#
# ![depicting_with_any.png](data:image/png;base64,...)
#
#
# ![counting_missing_values.png](data:image/png;base64,...)
#
# ![plotting_missing_values.png](data:image/png;base64,...)
#
# * Now that we know there are missing values in the dataset, what can we do about them?
#
# * One option is to remove the rows in the DataFrame that contain missing values using dropna method.
#
# ![removing_missing_values.png](data:image/png;base64,...)
#
# * Another option is to replace missing values with another value with 0.
#
# ![replacing_missing_values.png](data:image/png;base64,...)

# %% [markdown]
# **Exercises**

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Check individual values for missing values
print(avocados_2016.isna())

# Check each column for missing values
print(avocados_2016.isna().any())

# Bar plot of missing values by variable
avocados_2016.isna().sum().plot(kind="bar")

# Show plot
plt.show()

# %%
# Remove rows with missing values
avocados_complete = avocados_2016.dropna()

# Check if any columns contain missing values
print(avocados_complete.isna().any())

# %%
# List the columns with missing values
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]

# Create histograms showing the distributions cols_with_missing
avocados_2016[cols_with_missing].hist()

# Show the plot
plt.show()

# %%
# From previous step
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]
avocados_2016[cols_with_missing].hist()
plt.show()

# Fill in missing values with 0
avocados_filled = avocados_2016.fillna(0)

# Create histograms of the filled columns
avocados_filled[cols_with_missing].hist()

# Show the plot
plt.show()
