# %% [markdown]
# <a href="https://colab.research.google.com/github/iamisha/Python-Project-2024/blob/main/datacamp/pandas/introduction_to_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# **What's the point of pandas?**
#
# * Data Manipulation skill track
# * Data visualization skill track!!

# %% [markdown]
# **Pandas is built on NumPy and Matplotlib**

# %% [markdown]
# **Pandas is popular**
#
# **Rectangular data**

# %% [markdown]
# **pandas DataFrames**
#
# * Every value withing a columns has the same data type, either text or numeric, but different columns can contain different data types

# %% [markdown]
# ![exp_dataframe.png](data:image/png;base64,...)

# %% [markdown]
# ![info.png](data:image/png;base64,...)
#
#
# * The info method displays the names of columns, the data types they contain and whether they ahvae any missing values

# %% [markdown]
# **Exploring a DataFrame: .shape**
#
# * shape attribute contains a tuple that holds the number of rows followed by the number of columns
#
#
# dogs.shape
#
# **Output**: (7,6)

# %% [markdown]
# ![describe.png](data:image/png;base64,...)
#
# * the .describe() method computes some summary statistics for numerical columns, like mean and median

# %% [markdown]
# ![values.png](data:image/png;base64,...)
#
# * The values attribute, as you might expect, contains the data values in a 2-D NumPy array

# %% [markdown]
# ![columns.png](data:image/png;base64,...)

# %% [markdown]
# * The columns attribute contains column names
#
# * The index attribute contains row numbers or row names

# %% [markdown]
# ![index.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 1**

# %%
# Print the head of the homelessness data
print(homelessness.head())

# Print information about homelessness
print(homelessness.info())

# Print the shape of homelessness
print(homelessness.shape)

# Print a description of homelessness
print(homelessness.describe())

# %% [markdown]
# **Exercise 2**

# %%
# Import pandas using the alias pd
import pandas as pd

# Print the values of homelessness
print(homelessness.values)

# Print the column index of homelessness
print(homelessness.columns)

# Print the row index of homelessness
print(homelessness.index)
