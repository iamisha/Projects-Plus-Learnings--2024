# %% [markdown]
# <a href="https://colab.research.google.com/github/iamisha/Python-Project-2024/blob/branch-test-2/datacamp/data_visualization/relationsal_plots_and_subplots03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ![questions.png](data:image/png;base64,...)
#
# ![separate.png](data:image/png;base64,...)
#
# ![relplot.png](data:image/png;base64,...)
#
# ![relplot().png](data:image/png;base64,...)
#
# ![subplot_in_columns.png](data:image/png;base64,...)
#
# ![subset_inner_level_with_a_list.png](data:image/png;base64,...)
#
#
# ![subplots_in_rows_and_cols.png](data:image/png;base64,...)
#
# ![subrgoups.png](data:image/png;base64,...)
#
# ![wrapping_cols.png](data:image/png;base64,...)
#
# ![ordering_cols.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 1**

# %%
# Change to make subplots based on study time
sns.relplot(x="absences", y="G3",
            data=student_data,
            kind="scatter",
            col="study_time")

# Show plot
plt.show()

# %% [markdown]
# **Exercise 2**

# %%
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3",
            data=student_data,
            kind="scatter",
            row="study_time")

# Show plot
plt.show()

# %% [markdown]
# **Exercise 3**

# %%
# Create a scatter plot of G1 vs. G3
sns.relplot(x="G1", y="G3", kind="scatter",data=student_data)




# Show plot
plt.show()

# %% [markdown]
# **Exercise 3**

# %%
# Adjust to add subplots based on school support
sns.relplot(x="G1", y="G3",
            data=student_data,
            kind="scatter",
            col="schoolsup",
            col_order = ["yes", "no"]
            )

# Show plot
plt.show()

# %% [markdown]
# **Exercise 4**

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3",
            data=student_data,
            kind="scatter",
            col="schoolsup",
            row="famsup",
            col_order=["yes", "no"],
            row_order=["yes", "no"])

# Show plot
plt.show()
