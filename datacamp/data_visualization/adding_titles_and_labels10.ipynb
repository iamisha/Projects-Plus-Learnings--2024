# %% [markdown]
# ![s1.png](data:image/png;base64,...)
#
# ![s2.png](data:image/png;base64,...)
#
# ![s3.png](data:image/png;base64,...)
#
# ![s4.png](data:image/png;base64,...![s1.png](data:image/png;base64,...))

# %% [markdown]
# **Exercise 1**

# %%
# Create scatter plot
g = sns.relplot(x="weight",
                y="horsepower",
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Print type
print(type_of_g)

# %% [markdown]
# **Exercise 2**

# %%
# Create scatter plot
g = sns.relplot(x="weight",
                y="horsepower",
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")

# Show plot
plt.show()
