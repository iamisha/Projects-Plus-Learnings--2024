# %% [markdown]
# ![using_dataframe_with_countplot().png](data:image/png;base64,...)
#
# ![tidy.png](data:image/png;base64,...)
#
# * Seaborn works great with pandas DataFrames, but only if the DataFrame is "tidy".
#
# * Tidy data means that each observation has it's own row and each vairable has its own column
#
#
#
#
# ![untidy.png](data:image/png;base64,...)
#
#
# **tidy data is from the above table**
#
#
# **untidy data is from the above table**

# %% [markdown]
# **Exercise 1**

# %%
# Import pandas
import pandas as pd

# Create a DataFrame from csv file
df = pd.read_csv(csv_filepath)

# Print the head of df
print(df.head())

# %% [markdown]
# **Exercise 2**

# %%
# Import Matplotlib, pandas, and Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create a DataFrame from csv file
df = pd.read_csv(csv_filepath)


# Create a count plot with "Spiders" on the x-axis
sns.countplot(x="Spiders", data=df)


# Display the plot
plt.show()
