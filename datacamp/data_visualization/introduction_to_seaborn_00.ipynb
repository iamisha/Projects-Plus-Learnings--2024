# %% [markdown]
# ![seaborn.png](data:image/png;base64,...)
#
# ![adv_of_seaborn.png](data:image/png;base64,...)
#
# ![seaborn_useful.png](data:image/png;base64,...)
#
# ![example_1.png](data:image/png;base64,...)
#
# ![example_2.png](data:image/png;base64,...)

# %% [markdown]
# **Getting started**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
