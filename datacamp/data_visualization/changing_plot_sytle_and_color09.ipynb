# %% [markdown]
# ![s1.png](data:image/png;base64,...)
#
# ![s2.png](data:image/png;base64,...)
#
# ![s3.png](data:image/png;base64,...)
#
# ![s4.png](data:image/png;base64,...)
#
# ![s5.png](data:image/png;base64,...)
#
# ![s6.png](data:image/png;base64,...)
#
# ![s7.png](data:image/png;base64,...)
#
# ![s8.png](data:image/png;base64,...)
#
# ![s9.png](data:image/png;base64,...)
#
# ![s10.png](data:image/png;base64,...)
#
# ![s11.png](data:image/png;base64,...)
#
# ![s13.png](data:image/png;base64,...)
#
# ![s14.png](data:image/png;base64,...)
#
# ![s145png](data:application/octet-stream;base64,...)

# %% [markdown]
# **Exercise 1**

# %%
# Set the style to "whitegrid"

sns.set_style("whitegrid")

# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes",
                  "Often", "Always"]

sns.catplot(x="Parents Advice",
            data=survey_data,
            kind="count",
            order=category_order)

# Show plot
plt.show()

# %% [markdown]
# **Exercise 2**

# %%
# Change the color palette to "RdBu"
sns.set_style("whitegrid")
sns.set_palette("Purples")

# Create a count plot of survey responses
category_order = ["Never", "Rarely", "Sometimes",
                  "Often", "Always"]

sns.catplot(x="Parents Advice",
            data=survey_data,
            kind="count",
            order=category_order)

# Show plot
plt.show()

# %% [markdown]
# **Exercise 3**

# %%
# Set the style to "darkgrid"
sns.set_style("darkgrid")

# Set a custom color palette
sns.set_palette(["#39A7D0", "#36ADA4"])


# Create the box plot of age distribution by gender
sns.catplot(x="Gender", y="Age",
            data=survey_data, kind="box")

# Show plot
plt.show()
