# %% [markdown]
# ![i1.png](data:image/png;base64,...)
# ![i2.png](data:image/png;base64,...)
# ![i3.png](data:image/png;base64,...)
# ![i5.png](data:image/png;base64,...![i6.png](data:image/png;base64,...))
# ![i6.png](data:image/png;base64,...)
# ![i8.png](data:image/png;base64,...)

# %% [markdown]
# **Tensors: the building blocks of networks in PyTorch**

# %%
import torch

lst = [[1,2,3],[4,5,6]]
tensor = torch.tensor(lst)

# %% [markdown]
# **Tensor attributes**
#
# *   Tensor shape

# %%
tensor.shape
# Out:
# torch.Size([2, 3])

# %%
tensor.dtype
# Out:
# torch.int64

# %%
tensor.device
# Out:
# device(type='cpu')
