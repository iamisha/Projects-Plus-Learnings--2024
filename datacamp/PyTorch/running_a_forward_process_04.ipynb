# %% [markdown]
# ![s1.png](data:image/png;base64,...)
# ![s2.png](data:image/png;base64,...)
# ![s3.png](data:image/png;base64,...)
# ![s4.png](data:image/png;base64,...)
# ![s5.png](data:image/png;base64,...)
# ![s6.png](data:image/png;base64,...)
# ![s7.png](data:image/png;base64,...)
# ![s8.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn

input_tensor = torch.Tensor([[3, 4, 6, 2, 3, 6, 8, 9]])

# Implement a small neural network for binary classification
model = nn.Sequential(
  nn.Linear(8,1),
  nn.Sigmoid()
)

output = model(input_tensor)
print(output)
# Out:
# tensor([[0.9507]], grad_fn=<SigmoidBackward0>)

# %%
import torch
import torch.nn as nn

input_tensor = torch.Tensor([[3, 4, 6, 7, 10, 12, 2, 3, 6, 8, 9]])



# Implement a neural network for regression with exactly four linear layers
model = nn.Sequential(
    nn.Linear(11, 16),  # First linear layer with input size 8 and output size 16
    nn.ReLU(),         # Activation function
    nn.Linear(16, 32), # Second linear layer with input size 16 and output size 32
    nn.ReLU(),         # Activation function
    nn.Linear(32, 16), # Third linear layer with input size 32 and output size 16
    nn.ReLU(),         # Activation function
    nn.Linear(16, 1)   # Fourth linear layer with input size 16 and output size 1 (regression output)
)

output = model(input_tensor)
print(output)
# Out:
# tensor([[0.1439]], grad_fn=<AddmmBackward0>)

# %%
import torch
import torch.nn as nn

input_tensor = torch.Tensor([[3, 4, 6, 7, 10, 12, 2, 3, 6, 8, 9]])

# Update network below to perform a multi-class classification with four labels
model = nn.Sequential(
  nn.Linear(11, 20),
  nn.Linear(20, 12),
  nn.Linear(12, 6),
  nn.Linear(6, 4),
  nn.Softmax(dim=-1)
)

output = model(input_tensor)
print(output)
# Out:
# tensor([[0.0632, 0.1495, 0.2246, 0.5627]], grad_fn=<SoftmaxBackward0>)
