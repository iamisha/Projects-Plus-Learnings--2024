# %% [markdown]
# ![h1.png](data:image/png;base64,...)
#
# * The `heatmap` translates the numerical values in the matrix into a color coded grid
#
# ![h2.png](data:image/png;base64,...)
#
# ![h3.png](data:image/png;base64,...)
#
# * `annnot=True`: To turn on annotation in the individual cells.
# * `fmt`: ensure that the res are displayed in integer
# * `cbar=False`: Color bar is not displayed
# * `linewidth`: puts small spaces btween the cells
#
# ![h5.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 1**

# %%
# Create a crosstab table of the data
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])
print(pd_crosstab)

# Plot a heatmap of the table
sns.heatmap(pd_crosstab)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# **Exercise 2**

# %%
# Create the crosstab DataFrame
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])

# Plot a heatmap of the table with no color bar and using the BuGn palette
sns.heatmap(pd_crosstab, cbar=False, cmap="BuGn", linewidths=0.3)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

#Show the plot
plt.show()
plt.clf()
