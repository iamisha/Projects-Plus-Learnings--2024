# %% [markdown]
# **Introduction to regplot**
#
# * The `regplot` function generates a scatter plot with a regression line
#
# * Usage is similar to the `displot`
#
# * The `data` and `x` and `y` variable must be defined.
#
# ![s4.png](data:image/png;base64,...)
#
# **lmplot() builds on top of the base regplot()**
#
# * `regplot` - low level
#
# * `lmplot` - high level
#
#
#
# ![s1.png](data:image/png;base64,...)
#
#
# ![s18.png](data:image/png;base64,...)

# %% [markdown]
# **Exercise 1**

# %%
# Create a regression plot using hue
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums",
           hue="Region")

# Show the results
plt.show()

# %% [markdown]
# **Exercise 2**

# %%
# Create a regression plot with multiple rows
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums",
           row="Region")

# Show the plot
plt.show()
