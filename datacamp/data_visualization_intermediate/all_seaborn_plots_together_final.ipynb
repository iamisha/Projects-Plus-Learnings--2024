# %% [markdown]
# ![a1.png](data:image/png;base64,...)
#
# ![a2.png](data:image/png;base64,...)
#
# * A regression plot is an example of a plot that shows the relationship between two variables.
#
# ![a3.png](data:image/png;base64,...)
#
# ![a0.png](data:image/png;base64,...)
